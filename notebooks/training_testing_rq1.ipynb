# %% [markdown]
# ## Exploring the Data

# %%
import pandas as pd
import geopandas as gpd

#override max columns displayed
pd.set_option('display.max_columns', None)

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
path = '../data/consolidated/'
weather_data = pd.read_csv(path+'consolidated_weather_from_centroids.csv')
columns = list(weather_data.columns)
columns[0] = 'Hour'
weather_data.columns = columns

# %%
weather_data.head()
# Out:
#    Hour           valid_time       u10       v10        d2m        t2m  ssrd  \
# 0     0  2003-01-01 00:00:00  4.169556 -1.214157  259.06860  262.64050   0.0
# 1     1  2003-01-01 01:00:00  4.098358 -1.437256  259.24854  262.53380   0.0
# 2     2  2003-01-01 02:00:00  4.197708 -1.892502  258.54254  261.63712   0.0
# 3     3  2003-01-01 03:00:00  3.741165 -2.575897  255.86873  258.89398   0.0
# 4     4  2003-01-01 04:00:00  3.124802 -2.671005  255.42903  258.67328   0.0
#
#              tp  latitude  longitude                        file
# 0  1.907349e-06     48.75      -82.0  Northeast_centroid_weather
# 1  9.536743e-07     48.75      -82.0  Northeast_centroid_weather
# 2  3.814697e-06     48.75      -82.0  Northeast_centroid_weather
# 3  8.583069e-06     48.75      -82.0  Northeast_centroid_weather
# 4  9.536743e-06     48.75      -82.0  Northeast_centroid_weather

# %% [markdown]
# Checking if the centroids fall in the shape map.

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# read data
shapemap = gpd.read_file('../data/tenzones_ieso.geojson')
centroids = weather_data[['longitude', 'latitude', 'file']].drop_duplicates()

fig, ax = plt.subplots(figsize=(8, 6))

# plot map
shapemap.plot(ax=ax, color='lightgrey', edgecolor='black')

# plot centroids by file
for file_name, group in centroids.groupby('file'):
    ax.scatter(
        group['longitude'],
        group['latitude'],
        s=20,
        label=file_name
    )

# legend **outside** to the right
ax.legend(
    title="File",
    bbox_to_anchor=(1.05, 1),   # x, y position relative to the axes
    loc='upper left',
    borderaxespad=0
)

plt.tight_layout()
plt.show()

# %%
# now read demand data
demand_data = pd.read_csv(path+'consolidatedIESOdemand.csv')
demand_data.head()
# Out:
# /var/folders/b8/b4rqhqs11cbcqlzjryxb92lw0000gn/T/ipykernel_25288/3917683950.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   demand_data = pd.read_csv(path+'consolidatedIESOdemand.csv')
#          Date  Hour  Ontario Demand  Northwest  Northeast  Ottawa  East  \
# 0  2003-05-01     1           13702        809       1284     965   765
# 1  2003-05-01     2           13578        825       1283     923   752
# 2  2003-05-01     3           13411        834       1277     910   751
# 3  2003-05-01     4           13501        835       1277     922   758
# 4  2003-05-01     5           14010        847       1268     993   804
#
#    Toronto  Essa  Bruce  Southwest  Niagara  West  Zone Total Diff  Year
# 0     4422   622     41       2729      617  1611       13865  163  2003
# 1     4340   602     43       2731      615  1564       13678  100  2003
# 2     4281   591     45       2696      596  1553       13534  123  2003
# 3     4281   599     41       2724      609  1544       13590   89  2003
# 4     4469   643     51       2842      579  1592       14088   78  2003

# %%
demand_data.head()
# Out:
#          Date  Hour  Ontario Demand  Northwest  Northeast  Ottawa  East  \
# 0  2003-05-01     1           13702        809       1284     965   765
# 1  2003-05-01     2           13578        825       1283     923   752
# 2  2003-05-01     3           13411        834       1277     910   751
# 3  2003-05-01     4           13501        835       1277     922   758
# 4  2003-05-01     5           14010        847       1268     993   804
#
#    Toronto  Essa  Bruce  Southwest  Niagara  West  Zone Total Diff  Year
# 0     4422   622     41       2729      617  1611       13865  163  2003
# 1     4340   602     43       2731      615  1564       13678  100  2003
# 2     4281   591     45       2696      596  1553       13534  123  2003
# 3     4281   599     41       2724      609  1544       13590   89  2003
# 4     4469   643     51       2842      579  1592       14088   78  2003

# %% [markdown]
# Now for the price data

# %%
price_data = pd.read_csv(path+'prices_zonal.csv')

# %% [markdown]
# # Data Cleaning and Feature Engineering

# %%
# convert fromm kelvin to celsius
weather_data['temp_C_t2m'] = weather_data['t2m'] - 273.15

# %%
# show average temperatures
pd.set_option('display.float_format', lambda x: '%.9f' % x)
weather_data['temp_C_t2m'].describe()
# Out:
# count   2004720.000000000
# mean          6.662419457
# std          11.948470872
# min         -45.063900000
# 25%          -1.136880000
# 50%           7.163570000
# 75%          16.441212500
# max          37.167720000
# Name: temp_C_t2m, dtype: float64

# %%
import sys
import importlib

sys.path.append('../scripts/')
import FeatureEngineering
importlib.reload(FeatureEngineering)

dataset = FeatureEngineering.CleanedDataset(weather_data, demand_data, price_data)

# %%
datamerged = dataset.merge_datasets()
datamerged.sort_values(by=['file', 'Date']).head(5)
# Out:
#                        Date  Hour  Ontario Demand  Northwest  Northeast  \
# 1094537 2004-01-01 00:00:00     1           14703        811       1406
# 1094538 2004-01-01 01:00:00     2           14130        805       1412
# 1094539 2004-01-01 02:00:00     3           13575        795       1358
# 1094540 2004-01-01 03:00:00     4           13280        789       1355
# 1094541 2004-01-01 04:00:00     5           13219        779       1354
#
#          Ottawa  East  Toronto  Essa  Bruce  Southwest  Niagara  West  \
# 1094537    1197   903     4606   859     53       2790      542  1670
# 1094538    1095   889     4366   794     53       2698      516  1603
# 1094539    1053   842     4188   747     50       2582      507  1553
# 1094540    1027   817     4046   718     52       2549      517  1512
# 1094541    1018   811     3974   709     50       2534      529  1501
#
#          Zone Total Diff  Year          u10          v10           d2m  \
# 1094537       14837  134  2004 10.436722000 -2.628097500 268.592960000
# 1094538       14231  101  2004 10.491440000 -3.361358600 268.799200000
# 1094539       13675  100  2004  9.877060000 -4.244293000 269.045650000
# 1094540       13382  102  2004  8.785461000 -4.654403700 269.179720000
# 1094541       13259   40  2004  7.959579500 -4.542907700 269.336730000
#
#                   t2m        ssrd          tp     latitude     longitude  \
# 1094537 274.277950000 0.000000000 0.000000954 44.250000000 -81.750000000
# 1094538 274.068400000 0.000000000 0.000004768 44.250000000 -81.750000000
# 1094539 274.056100000 0.000000000 0.000012398 44.250000000 -81.750000000
# 1094540 274.193270000 0.000000000 0.000010490 44.250000000 -81.750000000
# 1094541 274.298160000 0.000000000 0.000006199 44.250000000 -81.750000000
#
#                            file  temp_C_t2m  Hour_of_Day  Reference_Richview  \
# 1094537  Bruce_centroid_weather 1.127950000            1        31.910000000
# 1094538  Bruce_centroid_weather 0.918400000            2        29.550000000
# 1094539  Bruce_centroid_weather 0.906100000            3        27.680000000
# 1094540  Bruce_centroid_weather 1.043270000            4        25.520000000
# 1094541  Bruce_centroid_weather 1.148160000            5        24.750000000
#
#          North West_Atikokan  North West_Pineportage  North West_Thunderbay  \
# 1094537         23.100000000            19.840000000           22.920000000
# 1094538         21.390000000            18.370000000           21.230000000
# 1094539         20.040000000            17.210000000           19.890000000
# 1094540         18.470000000            15.870000000           18.340000000
# 1094541         17.910000000            15.390000000           17.780000000
#
#          North East_Andrews  North East_Canyon  North East_NPIroqfalls  \
# 1094537        23.810000000       27.390000000            27.630000000
# 1094538        22.040000000       25.360000000            25.590000000
# 1094539        20.650000000       23.760000000            23.970000000
# 1094540        19.040000000       21.910000000            22.100000000
# 1094541        18.460000000       21.240000000            21.430000000
#
#          Ottawa_TAOHSC  East_Saunders  Toronto_Darlington  Essa_Desjoachims  \
# 1094537   32.240000000   30.640000000        31.260000000      29.200000000
# 1094538   29.850000000   28.380000000        28.950000000      27.040000000
# 1094539   27.970000000   26.580000000        27.120000000      25.330000000
# 1094540   25.790000000   24.510000000        25.000000000      23.350000000
# 1094541   25.000000000   23.770000000        24.250000000      22.650000000
#
#          Bruce_BruceB  South West_GerdauCam  Niagara_BECK2  West_Greenfield
# 1094537  30.340000000          30.610000000   31.260000000     30.670000000
# 1094538  28.100000000          28.340000000   28.950000000     28.400000000
# 1094539  26.320000000          26.550000000   27.120000000     26.610000000
# 1094540  24.260000000          24.480000000   25.000000000     24.530000000
# 1094541  23.530000000          23.740000000   24.250000000     23.790000000

# %%
# Quick missing data check
print(f"Merged dataset shape: {datamerged.shape}")
print(f"Missing values by column:")
missing = datamerged.isnull().sum()
for col in missing[missing > 0].index:
    pct = (missing[col] / len(datamerged) * 100)
    print(f"  {col}: {missing[col]:,} ({pct:.1f}%)")
if missing.sum() == 0:
    print("  No missing values found!")
# Out:
# Merged dataset shape: (1905110, 42)
# Missing values by column:
#   Hour_of_Day: 36,710 (1.9%)
#   Reference_Richview: 36,720 (1.9%)
#   North West_Atikokan: 36,720 (1.9%)
#   North West_Pineportage: 36,720 (1.9%)
#   North West_Thunderbay: 421,530 (22.1%)
#   North East_Andrews: 36,720 (1.9%)
#   North East_Canyon: 36,720 (1.9%)
#   North East_NPIroqfalls: 36,720 (1.9%)
#   Ottawa_TAOHSC: 36,720 (1.9%)
#   East_Saunders: 36,720 (1.9%)
#   Toronto_Darlington: 36,720 (1.9%)
#   Essa_Desjoachims: 36,720 (1.9%)
#   Bruce_BruceB: 36,720 (1.9%)
#   South West_GerdauCam: 36,740 (1.9%)
#   Niagara_BECK2: 36,720 (1.9%)
#   West_Greenfield: 36,720 (1.9%)

# %%
# check different types of missing values
empty_strings = datamerged[datamerged['North West_Thunderbay'] == '']
null_values = datamerged[datamerged['North West_Thunderbay'].isnull()]['Date'].dt.year.unique()

# 1094555   38.060000000   36.180000000        36.910000000      34.470000000
# 1094556   33.690000000   32.020000000        32.670000000      30.510000000
# 1094557   35.450000000   33.690000000        34.380000000      32.100000000
# 1094558   37.310000000   35.460000000        36.180000000      33.790000000
# 1094559   35.320000000   33.570000000        34.250000000      31.990000000
# 1094560   31.200000000   29.650000000        30.250000000      28.250000000
#
#          Bruce_BruceB  South West_GerdauCam  Niagara_BECK2  West_Greenfield
# 1094537  30.340000000          30.610000000   31.260000000     30.670000000
# 1094538  28.100000000          28.340000000   28.950000000     28.400000000
# 1094539  26.320000000          26.550000000   27.120000000     26.610000000
# 1094540  24.260000000          24.480000000   25.000000000     24.530000000
# 1094541  23.530000000          23.740000000   24.250000000     23.790000000
# 1094542  29.600000000          29.870000000   30.500000000     29.920000000
# 1094543  31.260000000          31.540000000   32.210000000     31.600000000
# 1094544  20.210000000          20.390000000   20.820000000     20.430000000
# 1094545  19.510000000          19.680000000   20.100000000     19.720000000
# 1094546  19.690000000          19.870000000   20.290000000     19.910000000
# 1094547  20.460000000          20.650000000   21.080000000     20.690000000
# 1094548  27.170000000          27.420000000   28.000000000     27.470000000
# 1094549  27.620000000          27.860000000   28.460000000     27.920000000
# 1094550  24.460000000          24.680000000   25.200000000     24.730000000
# 1094551  20.260000000          20.450000000   20.880000000     20.490000000
# 1094552  20.890000000          21.070000000   21.520000000     21.120000000
# 1094553  38.230000000          38.570000000   39.390000000     38.640000000
# 1094554  67.660000000          68.260000000   69.710000000     68.400000000
# 1094555  35.820000000          36.140000000   36.910000000     36.210000000
# 1094556  31.710000000          31.990000000   32.670000000     32.050000000
# 1094557  33.360000000          33.660000000   34.380000000     33.730000000
# 1094558  35.110000000          35.430000000   36.180000000     35.500000000
# 1094559  33.240000000          33.530000000   34.250000000     33.600000000
# 1094560  29.360000000          29.620000000   30.250000000     29.680000000

# %% [markdown]
# Test to ensure every day has a full 24 hours.

# %%
# merged_data['date_only'] = merged_data['Date'].dt.date

# hours_per_day = merged_data.groupby('date_only')['Date'].count()

# incomplete_days = hours_per_day[hours_per_day < 24]
# incomplete_days

# %%
# show average load over time
datamerged['Toronto'].describe()
# Out:
# count   1905110.000000000
# mean       5799.795471128
# std        1028.799832882
# min           0.000000000
# 25%        5004.000000000
# 50%        5803.000000000
# 75%        6478.000000000
# max       10285.000000000
# Name: Toronto, dtype: float64

# %%
# graph the average prices over time
plt.figure(figsize=(12, 6))
plt.plot(datamerged['Date'], datamerged['Toronto'], label='Toronto Load')
plt.xlabel('Date')
plt.ylabel('Load (MW)')
plt.title('Toronto Load Over Time')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.seasonal import seasonal_decompose
import numpy as np

# extract the series
prices = datamerged['Toronto']


# datamerged['Date'] = pd.to_datetime(datamerged['Date'])
datamerged.set_index('Date', inplace=True)
loads = datamerged['Toronto']


loads.plot(title='Toronto Electricity Load Over Time')
plt.xlabel('Time')
plt.ylabel('Load (MW)')
plt.show()

# 2. Autocorrelation plot to check cyclic patterns
plot_acf(loads.dropna(), lags=180)  # Increase lags if needed
plt.title('Autocorrelation of Toronto Electricity Load')
plt.show()

plt.show()

# %%
datamerged['Toronto'].describe()
# Out:
# count   1905110.000000000
# mean       5799.795471128
# std        1028.799832882
# min           0.000000000
# 25%        5004.000000000
# 50%        5803.000000000
# 75%        6478.000000000
# max       10285.000000000
# Name: Toronto, dtype: float64

# %% [markdown]
# # ARIMAX Model
#
# Building an ARIMAX (AutoRegressive Integrated Moving Average with eXogenous variables) model to predict electricity load usage using weather and demand data as exogenous features.

# %%
datamerged = dataset.merge_datasets()

datamerged = dataset.add_calendar_features(datamerged)
datamerged = datamerged[datamerged['file'] == 'Toronto_centroid_weather']

# %%
#create dummy variables for hour, month, weekday


print(datamerged.head())
print(datamerged.columns)


datamerged['Date'] = pd.to_datetime(datamerged['Date'])

# create dummy variables for hour, month, weekday
datamerged['hour'] = datamerged['Date'].dt.hour
datamerged['month'] = datamerged['Date'].dt.month
datamerged['weekday'] = datamerged['Date'].dt.weekday

# one hot
dummies = pd.get_dummies(datamerged[['hour', 'month', 'weekday']], columns=['hour', 'month', 'weekday'], prefix=['hour', 'month', 'weekday'])


datamerged = pd.concat([datamerged, dummies], axis=1)


print(datamerged.columns)

print(datamerged.filter(regex='hour_|month_|weekday_').head())
# Out:
#                        Date  Hour  Ontario Demand  Northwest  Northeast  \
# 1042570 2014-06-14 08:00:00     8           13929        455       1068
# 1042571 2014-06-14 09:00:00     9           14332        472       1123
# 1042572 2014-06-14 10:00:00    10           14559        487       1129
# 1042573 2014-06-14 11:00:00    11           14596        439       1125
# 1042574 2014-06-14 12:00:00    12           14385        401       1105
#
#          Ottawa  East  Toronto  Essa  Bruce  Southwest  Niagara  West  \
# 1042570     743   948     5128   805     81       2818      421  1387
# 1042571     782   974     5371   822     79       2867      436  1379
# 1042572     804   965     5517   808     80       2901      447  1362
# 1042573     818   981     5560   798     78       2887      438  1361
# 1042574     808   937     5548   764     77       2864      424  1341
#
#          Zone Total  Diff  Year         u10          v10           d2m  \
# 1042570       13855   -74  2014 5.528610000 -1.603500400 279.960720000
# 1042571       14307   -25  2014 5.732834000 -1.832565300 279.850000000
# 1042572       14500   -59  2014 4.753937000 -1.277130100 280.150270000
# 1042573       14486  -110  2014 5.058182000 -1.300323500 280.308840000
# 1042574       14270  -115  2014 5.077820000 -1.163436900 280.620970000
#
#                   t2m             ssrd          tp     latitude     longitude  \
# 1042570 284.740100000      0.000000000 0.000000000 43.750000000 -79.250000000
# 1042571 284.381100000      0.000000000 0.000000000 43.750000000 -79.250000000
# 1042572 284.704440000   6400.000000000 0.000000000 43.750000000 -79.250000000
# 1042573 284.658400000 153280.000000000 0.000000000 43.750000000 -79.250000000
# 1042574 284.849300000 637696.000000000 0.000000000 43.750000000 -79.250000000
#
#                              file   temp_C_t2m  Hour_of_Day  \
# 1042570  Toronto_centroid_weather 11.590100000            9
# 1042571  Toronto_centroid_weather 11.231100000           10
# 1042572  Toronto_centroid_weather 11.554440000           11
# 1042573  Toronto_centroid_weather 11.508400000           12
# 1042574  Toronto_centroid_weather 11.699300000           13
#
#          Reference_Richview  North West_Atikokan  North West_Pineportage  \
# 1042570        16.700000000         13.910000000            13.570000000
# 1042571        18.210000000         14.780000000            14.420000000
# 1042572        20.000000000         13.650000000            13.310000000
# 1042573        23.130000000         14.630000000            14.280000000
# 1042574        17.270000000         10.350000000            10.100000000
#
#          North West_Thunderbay  North East_Andrews  North East_Canyon  \
# 1042570           14.390000000        15.460000000       16.370000000
# 1042571           15.700000000        16.830000000       17.860000000
# 1042572           17.240000000        18.250000000       19.610000000
# 1042573           19.940000000        21.000000000       22.670000000
# 1042574           14.890000000        15.630000000       16.930000000
#
#          North East_NPIroqfalls  Ottawa_TAOHSC  East_Saunders  \
# 1042570            15.900000000   16.700000000   16.530000000
# 1042571            17.350000000   18.210000000   18.030000000
# 1042572            19.050000000   20.000000000   19.800000000
# 1042573            22.030000000   23.130000000   22.900000000
# 1042574            16.450000000   17.270000000   17.100000000
#
#          Toronto_Darlington  Essa_Desjoachims  Bruce_BruceB  \
# 1042570        16.700000000      16.530000000  16.210000000
# 1042571        18.210000000      18.030000000  17.680000000
# 1042572        20.000000000      19.800000000  19.420000000
# 1042573        23.130000000      22.900000000  22.450000000
# 1042574        17.270000000      17.100000000  16.770000000
#
#          South West_GerdauCam  Niagara_BECK2  West_Greenfield  Month  Day  \
# 1042570          16.700000000   16.530000000     16.530000000      6   14
# 1042571          18.210000000   18.030000000     18.030000000      6   14
# 1042572          20.000000000   19.800000000     19.800000000      6   14
# 1042573          23.130000000   22.900000000     22.900000000      6   14
# 1042574          17.270000000   17.100000000     17.100000000      6   14
#
#          Weekday  IsHoliday
# 1042570        5          0
# 1042571        5          0
# 1042572        5          0
# 1042573        5          0
# 1042574        5          0
# Index(['Date', 'Hour', 'Ontario Demand', 'Northwest', 'Northeast', 'Ottawa',
#        'East', 'Toronto', 'Essa', 'Bruce', 'Southwest', 'Niagara', 'West',
#        'Zone Total', 'Diff', 'Year', 'u10', 'v10', 'd2m', 't2m', 'ssrd', 'tp',
#        'latitude', 'longitude', 'file', 'temp_C_t2m', 'Hour_of_Day',
#        'Reference_Richview', 'North West_Atikokan', 'North West_Pineportage',
#        'North West_Thunderbay', 'North East_Andrews', 'North East_Canyon',
#        'North East_NPIroqfalls', 'Ottawa_TAOHSC', 'East_Saunders',
#        'Toronto_Darlington', 'Essa_Desjoachims', 'Bruce_BruceB',
#        'South West_GerdauCam', 'Niagara_BECK2', 'West_Greenfield', 'Month',
#        'Day', 'Weekday', 'IsHoliday'],
#       dtype='object')
# Index(['Date', 'Hour', 'Ontario Demand', 'Northwest', 'Northeast', 'Ottawa',
#        'East', 'Toronto', 'Essa', 'Bruce', 'Southwest', 'Niagara', 'West',
#        'Zone Total', 'Diff', 'Year', 'u10', 'v10', 'd2m', 't2m', 'ssrd', 'tp',
#        'latitude', 'longitude', 'file', 'temp_C_t2m', 'Hour_of_Day',
#        'Reference_Richview', 'North West_Atikokan', 'North West_Pineportage',
#        'North West_Thunderbay', 'North East_Andrews', 'North East_Canyon',
#        'North East_NPIroqfalls', 'Ottawa_TAOHSC', 'East_Saunders',
#        'Toronto_Darlington', 'Essa_Desjoachims', 'Bruce_BruceB',
#        'South West_GerdauCam', 'Niagara_BECK2', 'West_Greenfield', 'Month',
#        'Day', 'Weekday', 'IsHoliday', 'hour', 'month', 'weekday', 'hour_0',
#        'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7',
#        'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13',
#        'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19',
#        'hour_20', 'hour_21', 'hour_22', 'hour_23', 'month_1', 'month_2',
#        'month_3', 'month_4', 'month_5', 'month_6', 'month_7', 'month_8',
#        'month_9', 'month_10', 'month_11', 'month_12', 'weekday_0', 'weekday_1',
#        'weekday_2', 'weekday_3', 'weekday_4', 'weekday_5', 'weekday_6'],
#       dtype='object')
#          hour_0  hour_1  hour_2  hour_3  hour_4  hour_5  hour_6  hour_7  \
# 1042570   False   False   False   False   False   False   False   False
# 1042571   False   False   False   False   False   False   False   False
# 1042572   False   False   False   False   False   False   False   False
# 1042573   False   False   False   False   False   False   False   False
# 1042574   False   False   False   False   False   False   False   False
#
#          hour_8  hour_9  hour_10  hour_11  hour_12  hour_13  hour_14  hour_15  \
# 1042570    True   False    False    False    False    False    False    False
# 1042571   False    True    False    False    False    False    False    False
# 1042572   False   False     True    False    False    False    False    False
# 1042573   False   False    False     True    False    False    False    False
# 1042574   False   False    False    False     True    False    False    False
#
#          hour_16  hour_17  hour_18  hour_19  hour_20  hour_21  hour_22  \
# 1042570    False    False    False    False    False    False    False
# 1042571    False    False    False    False    False    False    False
# 1042572    False    False    False    False    False    False    False
# 1042573    False    False    False    False    False    False    False
# 1042574    False    False    False    False    False    False    False
#
#          hour_23  month_1  month_2  month_3  month_4  month_5  month_6  \
# 1042570    False    False    False    False    False    False     True
# 1042571    False    False    False    False    False    False     True
# 1042572    False    False    False    False    False    False     True
# 1042573    False    False    False    False    False    False     True
# 1042574    False    False    False    False    False    False     True
#
#          month_7  month_8  month_9  month_10  month_11  month_12  weekday_0  \
# 1042570    False    False    False     False     False     False      False
# 1042571    False    False    False     False     False     False      False
# 1042572    False    False    False     False     False     False      False
# 1042573    False    False    False     False     False     False      False
# 1042574    False    False    False     False     False     False      False
#
#          weekday_1  weekday_2  weekday_3  weekday_4  weekday_5  weekday_6
# 1042570      False      False      False      False       True      False
# 1042571      False      False      False      False       True      False
# 1042572      False      False      False      False       True      False
# 1042573      False      False      False      False       True      False
# 1042574      False      False      False      False       True      False

# %%
datamerged.shape
# Out:
# (190511, 92)

# %%
# the range of dates we can use for training and testing. this is to stop it from taking forever.

datamerged = datamerged[
    (datamerged['Date'].dt.year >= 2018) & 
    (datamerged['Date'].dt.year <= 2024)
]

# %%
datamerged.shape
# Out:
# (61368, 92)

# %%
# ============================================================================
# Reusable Data Preparation Pipeline should work for all the data models
# ============================================================================

def prepare_toronto_load_data(
    datamerged,
    zone='Toronto_centroid_weather',
    weather_vars=None,
    extra_lags=None,  # list of tuples: (original_col, new_name, lag_hours)
    test_weeks=1,
    include_daily_seasonality=True
):
    """
    Prepare Toronto load data for time series modeling.
    
    parameters:
    datamerged : pd.DataFrame
        The merged dataset with all features
    zone : str
        Location identifier to filter by
    weather_vars : list, optional
        List of weather variables to use.
    extra_lags : list of tuples, optional
        Each tuple: (column_name, new_column_name, lag_hours)
    test_weeks : int
        Number of weeks for test set (default: 1 week = 168 hours)
    include_daily_seasonality : bool
        Whether to include daily sin/cos features (default: True)
    
    Returns:
    --------
    dict containing:
        - 'train': training dataset with datetime index
        - 'test': test dataset with datetime index
        - 'target_train': target variable for training
        - 'target_test': target variable for testing
        - 'exog_features': list of exogenous feature column names
        - 'toronto_data': full processed dataset
    """
    
    if weather_vars is None:
        weather_vars = ['temp_C_t2m', 'u10', 'tp']
    if extra_lags is None:
        extra_lags = []
    
    hours_per_week = 168
    
    # filter and prepare
    toronto_data = datamerged[datamerged['file'] == zone].copy()
    toronto_data['Date'] = pd.to_datetime(toronto_data['Date'])
    toronto_data = toronto_data.set_index('Date').sort_index()
    
    # time index for fourier terms
    toronto_data["t"] = np.arange(len(toronto_data))
    
    # weekly seasonality
    period_weekly = 24 * 7
    toronto_data["sin_wk"] = np.sin(2 * np.pi * toronto_data["t"] / period_weekly)
    toronto_data["cos_wk"] = np.cos(2 * np.pi * toronto_data["t"] / period_weekly)
    
    # daily seasonality 
    if include_daily_seasonality:
        toronto_data["sin_day"] = np.sin(2 * np.pi * toronto_data["t"] / 24)
        toronto_data["cos_day"] = np.cos(2 * np.pi * toronto_data["t"] / 24)
    
    # lag weather variables by 1 week
    for var in weather_vars:
        toronto_data[f'{var}_lag1w'] = toronto_data[var].shift(168)
    
    # lag extra columns by custom hours
    for col, new_name, lag_hours in extra_lags:
        toronto_data[new_name] = toronto_data[col].shift(lag_hours)
    
    # drop rows with NaN after lagging. this happens at the start sometimes.
    cols_to_check = [f'{v}_lag1w' for v in weather_vars] + ['Toronto']
    if extra_lags:
        cols_to_check += [new_name for _, new_name, _ in extra_lags]
    toronto_data = toronto_data.dropna(subset=cols_to_check)
    
    # e xtract dummy variables 
    hour_dummies = [c for c in toronto_data.columns if c.startswith('hour_')][1:]
    month_dummies = [c for c in toronto_data.columns if c.startswith('month_')][1:]
    weekday_dummies = [c for c in toronto_data.columns if c.startswith('weekday_')][1:]
    
    # bild exogenous features list ---
    seasonal_features = ["sin_wk", "cos_wk"]
    if include_daily_seasonality:
        seasonal_features += ['sin_day', 'cos_day']

    exog_features = (
        hour_dummies +
        month_dummies +
        weekday_dummies +
        [f'{v}_lag1w' for v in weather_vars] +
        seasonal_features
    )
    
    # holidays addition
    if 'IsHoliday' in toronto_data.columns:
        exog_features += ['IsHoliday']
    
    if extra_lags:
        exog_features += [new_name for _, new_name, _ in extra_lags]
    
    # train/test split
    train = toronto_data.iloc[:-hours_per_week * test_weeks]
    test = toronto_data.iloc[-hours_per_week * test_weeks:]
    
    # ensure numeric for exogenous features
    for df in [train, test]:
        df[exog_features] = df[exog_features].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float)
    
    target_train = train['Toronto'].astype(float)
    target_test = test['Toronto'].astype(float)
    
    return {
        'train': train,
        'test': test,
        'target_train': target_train,
        'target_test': target_test,
        'exog_features': exog_features,
        'toronto_data': toronto_data
    }

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt


data = prepare_toronto_load_data(
    datamerged,
    zone='Toronto_centroid_weather',
    weather_vars=['temp_C_t2m', 'u10', 'tp'],
    extra_lags=[
        ('Toronto', '1w_load', 168),
        ('Toronto_Darlington', '1w_price', 168)
    ],
    test_weeks=40,
    include_daily_seasonality=True
)

train = data['train']
test = data['test']
target_train = data['target_train']
target_test = data['target_test']
exog_features = data['exog_features']

# ----------------------
# Rolling week-ahead forecast
# ----------------------
forecast_horizon = 168  # 1 week
max_weeks = None       # None = forecast full test set

all_pred = []
all_actual = []

test_start_idx = 0
test_end_idx = len(test)
week_count = 0

while test_start_idx < test_end_idx:
    # slice current week for forecast
    current_end_idx = test_start_idx + forecast_horizon
    if current_end_idx > test_end_idx:
        current_end_idx = test_end_idx  # handle last partial week

    exog_forecast = test[exog_features].iloc[test_start_idx:current_end_idx]

    # fit arimax. ariamx is just sarimax without any seasonal ordering
    model = SARIMAX(
        target_train,
        exog=train[exog_features],
        order=(2, 1, 1),
        seasonal_order=(0, 0, 0, 0),
        enforce_stationarity=False,
        enforce_invertibility=False
    )
    results = model.fit(disp=False)

    # forecast 1 week
    forecast = results.get_forecast(steps=len(exog_forecast), exog=exog_forecast)
    pred_mean = forecast.predicted_mean.values

    # store predictions and actuals
    all_pred.extend(pred_mean)
    all_actual.extend(target_test.iloc[test_start_idx:current_end_idx].values)

    # move to next week
    test_start_idx += forecast_horizon
    week_count += 1
    if max_weeks is not None and week_count >= max_weeks:
        break

# ----------------------
# Evaluate
# ----------------------
rmse = np.sqrt(mean_squared_error(all_actual, all_pred))
print(f'Rolling ARIMAX RMSE: {rmse:.2f}')

# ----------------------
# Plot results
# ----------------------
plt.figure(figsize=(14, 6))
plt.plot(test.index, target_test, label='Actual')
plt.plot(test.index[:len(all_pred)], all_pred, linestyle='--', label='Predicted')
plt.title('Toronto Load: Rolling Week-Ahead ARIMAX Forecast')
plt.xlabel('Date')
plt.ylabel('Load (MW)')
plt.legend()
plt.show()

# ----------------------
# last model summary
# ----------------------
print(results.summary())
# Out:
# /var/folders/b8/b4rqhqs11cbcqlzjryxb92lw0000gn/T/ipykernel_25288/576012382.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[exog_features] = df[exog_features].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float)
# /var/folders/b8/b4rqhqs11cbcqlzjryxb92lw0000gn/T/ipykernel_25288/576012382.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[exog_features] = df[exog_features].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency h will be used.
#   self._init_dates(dates, freq)
# Rolling ARIMAX RMSE: 746.26
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                Toronto   No. Observations:                54480
# Model:               SARIMAX(2, 1, 1)   Log Likelihood             -300577.285
# Date:                Thu, 11 Dec 2025   AIC                         601262.571
# Time:                        14:07:38   BIC                         601743.469
# Sample:                    01-08-2018   HQIC                        601412.612
#                          - 03-26-2024
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# cos_wk             -66.0358     12.841     -5.143      0.000     -91.203     -40.868
# sin_day           -173.0311      4.158    -41.613      0.000    -181.181    -164.881
# cos_day           -248.9620      4.645    -53.592      0.000    -258.067    -239.857
# IsHoliday           -9.7080      8.929     -1.087      0.277     -27.208       7.792
# 1w_load              0.6675      0.002    344.283      0.000       0.664       0.671
# 1w_price             0.0038      0.002      1.532      0.125      -0.001       0.009
# ar.L1                1.5413      0.004    391.418      0.000       1.534       1.549
# ar.L2               -0.6125      0.002   -251.645      0.000      -0.617      -0.608
# ma.L1               -0.9178      0.004   -246.636      0.000      -0.925      -0.911
# sigma2            3627.3093     10.152    357.292      0.000    3607.411    3647.207
# ===================================================================================
# Ljung-Box (L1) (Q):                   5.64   Jarque-Bera (JB):            334979.30
# Prob(Q):                              0.02   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.01   Skew:                            -0.02
# Prob(H) (two-sided):                  0.37   Kurtosis:                        15.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.08e+20. Standard errors may be unstable.

# %%
# show model summary
print(rmse)
# Out:
# 746.2645811681301

# %% [markdown]
# ## Bayesian Ridge Regression

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# ----------------------
# Use prepared data
# ----------------------
data = prepare_toronto_load_data(
    datamerged,
    zone='Toronto_centroid_weather',
    weather_vars=['temp_C_t2m', 'u10', 'tp'],
    extra_lags=[  
        ('Toronto', '1w_load', 168),
        ('Toronto_Darlington', '1w_price', 168)
    ],
    test_weeks=40,
    include_daily_seasonality=True
)

full = data["toronto_data"]        # <- full continuous dataset (train+test)
exog_features = data["exog_features"]
target_col = "Toronto"

# indices
test = data["test"]
test_start_idx = full.index.get_loc(test.index[0])
test_end_idx   = full.index.get_loc(test.index[-1])

# ----------------------
# Rolling week-ahead forecast (expanding window)
# ----------------------
forecast_horizon = 168
max_weeks = 40

all_pred  = []
all_lower = []
all_upper = []
all_actual = []

current_train_end = test_start_idx
week_count = 0

while current_train_end < test_end_idx and week_count < max_weeks:

    # Expanding training window
    train_df = full.iloc[:current_train_end]

    # Forecast window
    forecast_df = full.iloc[current_train_end : current_train_end + forecast_horizon]

    # Stop if the last week is incomplete
    if len(forecast_df) < forecast_horizon:
        break

    X_train = train_df[exog_features].astype(float)
    y_train = train_df[target_col].astype(float)

    X_forecast = forecast_df[exog_features].astype(float)
    y_forecast = forecast_df[target_col].astype(float)

    # Scale features without leakage
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_forecast_scaled = scaler.transform(X_forecast)

    # Fit Bayesian Ridge
    model = BayesianRidge()
    model.fit(X_train_scaled, y_train)

    # Predict with uncertainty
    mean_pred, std_pred = model.predict(X_forecast_scaled, return_std=True)

    lower = mean_pred - 1.96 * std_pred
    upper = mean_pred + 1.96 * std_pred

    # Store forecasts
    all_pred.extend(mean_pred)
    all_lower.extend(lower)
    all_upper.extend(upper)
    all_actual.extend(y_forecast.values)

    # Move rolling window forward by one week
    current_train_end += forecast_horizon
    week_count += 1


# ----------------------
# Evaluate
# ----------------------
rmse = np.sqrt(mean_squared_error(all_actual, all_pred))
print(f"Rolling Bayesian Ridge RMSE: {rmse:.2f}")

# ----------------------
# Plot results with credible intervals
# ----------------------
pred_index = full.index[test_start_idx : test_start_idx + len(all_pred)]

plt.figure(figsize=(15, 6))
plt.plot(pred_index, all_actual, label="Actual")
plt.plot(pred_index, all_pred, linestyle="--", label="Predicted")

plt.fill_between(
    pred_index,
    all_lower,
    all_upper,
    color="gray",
    alpha=0.3,
    label="95% Credible Interval"
)

plt.title("Toronto Load: Rolling Week-Ahead Forecast (Bayesian Ridge)")
plt.xlabel("Date")
plt.ylabel("Load (MW)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/b8/b4rqhqs11cbcqlzjryxb92lw0000gn/T/ipykernel_25288/576012382.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[exog_features] = df[exog_features].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float)
# /var/folders/b8/b4rqhqs11cbcqlzjryxb92lw0000gn/T/ipykernel_25288/576012382.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[exog_features] = df[exog_features].apply(pd.to_numeric, errors='coerce').fillna(0).astype(float)
# Rolling Bayesian Ridge RMSE: 517.88

# %%
rmse
# Out:
# np.float64(517.8794876722415)

# %%
# ----------------------
# Interval Accuracy Evaluation
# ----------------------

actual_arr = np.array(all_actual)
lower_arr  = np.array(all_lower)
upper_arr  = np.array(all_upper)

# Boolean array: did the interval contain the actual?
covered = (actual_arr >= lower_arr) & (actual_arr <= upper_arr)

coverage_rate = covered.mean() * 100
avg_width = np.mean(upper_arr - lower_arr)

print(f"95% Credible Interval Coverage: {coverage_rate:.2f}%")
print(f"Average Interval Width: {avg_width:.2f} MW")

# check where the model is over/under-confident
miss_idx = np.where(~covered)[0]
print(f"Total misses: {len(miss_idx)}")

plt.figure(figsize=(15,4))
plt.plot(pred_index, actual_arr, label="Actual", color="black")
plt.fill_between(pred_index, lower_arr, upper_arr, alpha=0.2)

# highlight misses in red
plt.scatter(
    pred_index[miss_idx],
    actual_arr[miss_idx],
    color="red",
    label="Missed points (outside interval)"
)

plt.title("Uncertainty Interval Misses (Bayesian Ridge)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 95% Credible Interval Coverage: 92.26%
# Average Interval Width: 1865.57 MW
# Total misses: 520

# %%
# show which features are most important
feature_importance = pd.Series(np.abs(model.coef_), index=exog_features)
feature_importance = feature_importance.sort_values(ascending=False)

# %%
feature_importance
# Out:
# cos_day            308.140606845
# 1w_load            274.026859427
# month_4            159.726294642
# month_10           150.374722209
# sin_day            149.222985928
# month_5            142.845788893
# month_7            123.723242759
# weekday_6          118.416677399
# hour_20            112.272570850
# hour_19            109.661494766
# weekday_5          108.539150604
# IsHoliday          101.523347336
# hour_18             99.649229462
# hour_21             93.072374232
# month_3             91.868294293
# cos_wk              88.123970019
# month_11            85.200055411
# hour_17             84.462043705
# month_9             81.667297398
# month_8             70.824195022
# weekday_3           67.293517240
# weekday_2           65.421888854
# sin_wk              63.608744488
# hour_16             60.719406081
# hour_22             58.942147591
# hour_9              53.787064470
# hour_10             53.086758871
# month_12            52.658258284
# hour_8              49.921496804
# hour_11             47.487666660
# hour_3              42.211016708
# hour_4              41.569300974
# weekday_4           39.542900180
# hour_7              39.331660786
# hour_12             38.723932848
# weekday_1           38.622684238
# hour_15             38.459268024
# hour_2              32.866214939
# hour_13             30.136275694
# hour_14             28.338002283
# temp_C_t2m_lag1w    26.990062952
# hour_23             25.153560145
# hour_5              23.487634425
# hour_1              18.880605129
# month_6             18.752010581
# month_2             18.333882727
# hour_6              11.651980392
# 1w_price             4.210576430
# u10_lag1w            2.665481556
# tp_lag1w             1.403786612
# dtype: float64

# %%
# check what's actually happening with the dates to ensure no leakage.
print(f"Test period start: {test.index[0]}")
print(f"Test period end: {test.index[-1]}")
print(f"Test set size: {len(test)} hours")
print(f"Test set size in days: {len(test) / 24} days")
print(f"Test set size in weeks: {len(test) / 168} weeks")


print(f"\nTrain period end: {train.index[-1]}")
print(f"Test period start: {test.index[0]}")
print(f"Gap between train and test: {test.index[0] - train.index[-1]}")
# Out:
# Test period start: 2024-03-27 00:00:00
# Test period end: 2024-12-31 23:00:00
# Test set size: 6720 hours
# Test set size in days: 280.0 days
# Test set size in weeks: 40.0 weeks
#
# Train period end: 2024-03-26 23:00:00
# Test period start: 2024-03-27 00:00:00
# Gap between train and test: 0 days 01:00:00

# %% [markdown]
# ## Prophet

# %%
# %pip install cmdstanpy prophet
# Out:
# Requirement already satisfied: cmdstanpy in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (1.3.0)
# Requirement already satisfied: prophet in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (1.2.1)
# Requirement already satisfied: pandas in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from cmdstanpy) (2.3.3)
# Requirement already satisfied: numpy>=1.21 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from cmdstanpy) (2.3.5)
# Requirement already satisfied: tqdm in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from cmdstanpy) (4.67.1)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from cmdstanpy) (0.5.1)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from prophet) (3.10.7)
# Requirement already satisfied: holidays<1,>=0.25 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from prophet) (0.85)
# Requirement already satisfied: importlib_resources in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from prophet) (6.5.2)
# Requirement already satisfied: python-dateutil in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from pandas->cmdstanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from pandas->cmdstanpy) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/isaacwood/Documents/School/CISC 451/IESO ML Project/.venv/lib/python3.14/site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
from contextlib import contextmanager

@contextmanager
def suppress_stdout_stderr():
    """Suppress stdout and stderr output."""
    with open(os.devnull, 'w') as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

# %%
data['test']
# Out:
#                      Hour  Ontario Demand  Northwest  Northeast  Ottawa  East  \
# Date
# 2024-03-27 00:00:00     0           13370        611       1299     803   692
# 2024-03-27 01:00:00     1           13430        609       1285     792   728
# 2024-03-27 02:00:00     2           13433        612       1279     776   750
# 2024-03-27 03:00:00     3           13451        620       1266     802   766
# 2024-03-27 04:00:00     4           13636        616       1231     836   792
# ...                   ...             ...        ...        ...     ...   ...
# 2024-12-31 19:00:00    19           16373        612       1375    1098  1003
# 2024-12-31 20:00:00    20           15767        613       1364    1068   925
# ...                         ...          ...          ...         ...
# 2024-12-31 19:00:00 0.999300705 -0.037391194 -0.965925826 0.258819045
# 2024-12-31 20:00:00 0.997203797 -0.074730094 -0.866025404 0.500000000
# 2024-12-31 21:00:00 0.993712210 -0.111964476 -0.707106781 0.707106781
# 2024-12-31 22:00:00 0.988830826 -0.149042266 -0.500000000 0.866025404
# 2024-12-31 23:00:00 0.982566473 -0.185911607 -0.258819045 0.965925826
#
#                      temp_C_t2m_lag1w   u10_lag1w    tp_lag1w        1w_load  \
# Date
# 2024-03-27 00:00:00       1.296600000 6.364715600 0.000006676 5081.000000000
# 2024-03-27 01:00:00       1.369960000 5.729049700 0.000002384 4945.000000000
# 2024-03-27 02:00:00       1.303280000 5.587249800 0.000001907 4859.000000000
# 2024-03-27 03:00:00       1.118300000 5.661270000 0.000001907 4873.000000000
# 2024-03-27 04:00:00       1.025050000 5.582336400 0.000002861 5106.000000000
# ...                               ...         ...         ...            ...
# 2024-12-31 19:00:00       0.434630000 0.422637940 0.000000000 6031.000000000
# 2024-12-31 20:00:00       0.501250000 1.015808100 0.000000477 5880.000000000
# 2024-12-31 21:00:00       0.485250000 1.207824700 0.000003815 5730.000000000
# 2024-12-31 22:00:00       0.722500000 1.373870800 0.000003815 5511.000000000
# 2024-12-31 23:00:00       0.219020000 0.741027830 0.000002384 5274.000000000
#
#                         1w_price
# Date
# 2024-03-27 00:00:00 26.940000000
# 2024-03-27 01:00:00 20.860000000
# 2024-03-27 02:00:00 21.060000000
# 2024-03-27 03:00:00 14.550000000
# 2024-03-27 04:00:00 17.780000000
# ...                          ...
# 2024-12-31 19:00:00 40.340000000
# 2024-12-31 20:00:00 39.070000000
# 2024-12-31 21:00:00 38.570000000
# 2024-12-31 22:00:00 34.600000000
# 2024-12-31 23:00:00 34.070000000
#
# [6720 rows x 55 columns]

# %%
# --- Prophet Rolling Week-Ahead Forecasting (6 weeks only) ---
from prophet import Prophet
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

forecast_horizon = 168  
max_weeks = 40            

full = data["toronto_data"] ## same as in bayesian ridge regression. may change later for clarity
exog_features = data["exog_features"]

# test set boundaries from your data prep
test = data["test"]
test_start_idx = full.index.get_loc(test.index[0])
test_end_idx = full.index.get_loc(test.index[-1])

# storage
all_forecasts = []
all_timestamps = []

current_train_end = test_start_idx
week_count = 0


while current_train_end < test_end_idx and week_count < max_weeks:


    train_df = full.iloc[:current_train_end]
    future_df = full.iloc[current_train_end : current_train_end + forecast_horizon]

    if len(future_df) < forecast_horizon:
        break


    prophet_train = pd.DataFrame({
        "ds": train_df.index,
        "y": train_df["Toronto"]
    })
    
    # Filter out Fourier terms for Prophet (it has its own seasonality)
    fourier_terms = [f for f in exog_features if 'sin' in f or 'cos' in f]
    prophet_exog_features = [f for f in exog_features if f not in fourier_terms]
    
    for col in prophet_exog_features:
        prophet_train[col] = train_df[col].values

    # build Prophet model

    model = Prophet(
        yearly_seasonality=True,
        weekly_seasonality=True,
        daily_seasonality=True
    )

    for col in prophet_exog_features:
        model.add_regressor(col)

    model.fit(prophet_train)


    # build future_dataframe

    prophet_future = pd.DataFrame({"ds": future_df.index})
    for col in prophet_exog_features:
        prophet_future[col] = future_df[col].values


    # forecast 168 hours

    forecast = model.predict(prophet_future)

    all_forecasts.append(forecast["yhat"].values)
    all_timestamps.append(future_df.index.values)

    # Move forward one week
    current_train_end += forecast_horizon
    week_count += 1

# ---------------------------
# concatenate forecasts

preds = np.concatenate(all_forecasts)
pred_times = np.concatenate(all_timestamps)

pred_series = pd.Series(preds, index=pred_times)
actual_series = full.loc[pred_series.index, "Toronto"]


# evaluate

rmse = np.sqrt(mean_squared_error(actual_series, pred_series))
print(f"Rolling Week-Ahead RMSE for 40 weeks: {rmse:.2f}")

#plotting
plt.figure(figsize=(16, 6))
plt.plot(actual_series.index, actual_series.values, label="Actual", linewidth=2)
plt.plot(pred_series.index, pred_series.values, label="Prophet 40-Week Rolling Forecast", linestyle="--")
plt.title("Toronto Load – First 40 Rolling Week-Ahead Predictions")
plt.xlabel("Date")
plt.ylabel("Load (MW)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 11:03:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:03:49 - cmdstanpy - INFO - Chain [1] done processing
# 11:03:51 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:03 - cmdstanpy - INFO - Chain [1] done processing
# 11:04:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:18 - cmdstanpy - INFO - Chain [1] done processing
# 11:04:20 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:34 - cmdstanpy - INFO - Chain [1] done processing
# 11:04:37 - cmdstanpy - INFO - Chain [1] start processing
# 11:04:58 - cmdstanpy - INFO - Chain [1] done processing
# 11:05:01 - cmdstanpy - INFO - Chain [1] start processing
# 11:05:20 - cmdstanpy - INFO - Chain [1] done processing
# 11:05:22 - cmdstanpy - INFO - Chain [1] start processing
# 11:05:37 - cmdstanpy - INFO - Chain [1] done processing
# 11:05:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:05:54 - cmdstanpy - INFO - Chain [1] done processing
# 11:05:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:06:11 - cmdstanpy - INFO - Chain [1] done processing
# 11:06:13 - cmdstanpy - INFO - Chain [1] start processing
# 11:06:29 - cmdstanpy - INFO - Chain [1] done processing
# 11:06:31 - cmdstanpy - INFO - Chain [1] start processing
# 11:06:56 - cmdstanpy - INFO - Chain [1] done processing
# 11:06:58 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:22 - cmdstanpy - INFO - Chain [1] done processing
# 11:07:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:07:45 - cmdstanpy - INFO - Chain [1] done processing
# 11:07:48 - cmdstanpy - INFO - Chain [1] start processing
# 11:08:09 - cmdstanpy - INFO - Chain [1] done processing
# 11:08:11 - cmdstanpy - INFO - Chain [1] start processing
# 11:08:28 - cmdstanpy - INFO - Chain [1] done processing
# 11:08:31 - cmdstanpy - INFO - Chain [1] start processing
# 11:08:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:08:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:18 - cmdstanpy - INFO - Chain [1] done processing
# 11:09:20 - cmdstanpy - INFO - Chain [1] start processing
# 11:09:39 - cmdstanpy - INFO - Chain [1] done processing
# 11:09:41 - cmdstanpy - INFO - Chain [1] start processing
# 11:10:02 - cmdstanpy - INFO - Chain [1] done processing
# 11:10:04 - cmdstanpy - INFO - Chain [1] start processing
# 11:10:27 - cmdstanpy - INFO - Chain [1] done processing
# 11:10:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:10:55 - cmdstanpy - INFO - Chain [1] done processing
# 11:10:57 - cmdstanpy - INFO - Chain [1] start processing
# 11:11:21 - cmdstanpy - INFO - Chain [1] done processing
# 11:11:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:11:40 - cmdstanpy - INFO - Chain [1] done processing
# 11:11:42 - cmdstanpy - INFO - Chain [1] start processing
# 11:12:00 - cmdstanpy - INFO - Chain [1] done processing
# 11:12:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:12:22 - cmdstanpy - INFO - Chain [1] done processing
# 11:12:25 - cmdstanpy - INFO - Chain [1] start processing
# 11:12:45 - cmdstanpy - INFO - Chain [1] done processing
# 11:12:47 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:02 - cmdstanpy - INFO - Chain [1] done processing
# 11:13:05 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:18 - cmdstanpy - INFO - Chain [1] done processing
# 11:13:20 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:36 - cmdstanpy - INFO - Chain [1] done processing
# 11:13:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:13:51 - cmdstanpy - INFO - Chain [1] done processing
# 11:13:53 - cmdstanpy - INFO - Chain [1] start processing
# 11:14:09 - cmdstanpy - INFO - Chain [1] done processing
# 11:14:11 - cmdstanpy - INFO - Chain [1] start processing
# 11:14:27 - cmdstanpy - INFO - Chain [1] done processing
# 11:14:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:14:43 - cmdstanpy - INFO - Chain [1] done processing
# 11:14:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:15:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:15:03 - cmdstanpy - INFO - Chain [1] start processing
# 11:15:23 - cmdstanpy - INFO - Chain [1] done processing
# 11:15:25 - cmdstanpy - INFO - Chain [1] start processing
# 11:15:43 - cmdstanpy - INFO - Chain [1] done processing
# 11:15:45 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:01 - cmdstanpy - INFO - Chain [1] done processing
# 11:16:04 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:22 - cmdstanpy - INFO - Chain [1] done processing
# 11:16:24 - cmdstanpy - INFO - Chain [1] start processing
# 11:16:43 - cmdstanpy - INFO - Chain [1] done processing
# 11:16:46 - cmdstanpy - INFO - Chain [1] start processing
# 11:17:07 - cmdstanpy - INFO - Chain [1] done processing
# Rolling Week-Ahead RMSE for 40 weeks: 511.30

# %%
print(f"Prophet RMSE for week-ahead forecast: {rmse:.2f}")
# Out:
# Prophet RMSE for week-ahead forecast: 511.08

# %%
full.shape
# Out:
# (61200, 101)
